# %%
# General use
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Mappers
from src.lib.utils.constants import country_code_map, event_code_map, geo_type_code_map, role_code_map, gov_arm_code_map, country_role_code_map, country_gov_arm_code_map

# Get path and env
from src.lib.utils.path_finder import PROJECT_DIRECTORY
from src.lib.utils.config import config
from src.lib.utils.env_checker import running_environment
env = running_environment()

# Notebook behavior
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
seed = config["SEED"]
filler = "__NULL__"
pd.set_option('display.max_rows', 100)

# %%
# Load data
fname = "cleaned_events.parquet"
if env=="sagemaker":
    fpath = f"s3://news-s3/data/cleaned/{fname}"
else:
    fpath = PROJECT_DIRECTORY.joinpath(f"data/cleaned/{fname}")
df = pd.read_parquet(fpath).fillna(np.nan)
df.shape
df.head()
# Out:
# (883292, 13)
#               QuadClass   SQLDATE Actor1CountryCode Actor2CountryCode  \
# GLOBALEVENTID
# 1078326026            1  20230101               NaN               NaN
# 1078326027            4  20230101               NaN               NaN
# 1078326030            4  20230101               NaN               NaN
# 1078326080            2  20230101               NaN               RUS
# 1078326081            2  20230101               NaN               RUS
#
#                GoldsteinScore CAMEOEvent EventDateTime Actor1Code Actor1Name  \
# GLOBALEVENTID
# 1078326026                2.8        043    2023-01-01        NaN        NaN
# 1078326027               -5.0        173    2023-01-01        NaN        NaN
# 1078326030              -10.0        190    2023-01-01        NaN        NaN
# 1078326080               10.0       0874    2023-01-01        NaN        NaN
# 1078326081               10.0       0874    2023-01-01        NaN        NaN
#
#               Actor1Geo_FullName Actor2Code      Actor2Name  \
# GLOBALEVENTID
# 1078326026                   NaN        COP  POLICE OFFICER
# 1078326027                   NaN        COP       DETECTIVE
# 1078326030                   NaN        COP       DETECTIVE
# 1078326080                   NaN        RUS          MOSCOW
# 1078326081                   NaN        RUS          MOSCOW
#
#                                        Actor2Geo_FullName
# GLOBALEVENTID
# 1078326026                                            NaN
# 1078326027                                            NaN
# 1078326030                                            NaN
# 1078326080                         Moscow, Moskva, Russia
# 1078326081     Monroe County, Pennsylvania, United States

# %%
# Check columns
tmp = df.apply([pd.Series.nunique, lambda ser: ser.isna().mean()]).T
tmp.columns = ["nunique", "sparsity"]
tmp.sort_values("sparsity", ascending=True)
# Out:
#                     nunique  sparsity
# QuadClass               4.0  0.000000
# SQLDATE               441.0  0.000000
# GoldsteinScore         42.0  0.000000
# CAMEOEvent            228.0  0.000000
# EventDateTime       36085.0  0.000000
# Actor1Code           2987.0  0.077113
# Actor1Name           3544.0  0.077113
# Actor1Geo_FullName   9939.0  0.101719
# Actor2Code           2780.0  0.259698
# Actor2Name           3334.0  0.259698
# Actor2Geo_FullName   9033.0  0.273676
# Actor1CountryCode     216.0  0.370911
# Actor2CountryCode     214.0  0.491269

# %%
# Check how much can be matched
country_keys = list(country_code_map.keys())
role_keys = list(role_code_map.keys())
country_role_keys = list(country_role_code_map.keys())
gov_arm_keys = list(gov_arm_code_map.keys())
country_gov_arm_keys = list(country_gov_arm_code_map.keys())
known_keys =  country_keys + role_keys + country_role_keys + gov_arm_keys + country_gov_arm_keys

fxn = lambda ser: {"Sparsity": ser.isna().mean(), 
                   "Country Keys":ser.dropna().isin(country_keys).mean(), 
                   "Role Keys":ser.dropna().isin(role_keys).mean(), 
                   "Country Role Keys":ser.dropna().isin(country_role_keys).mean(), 
                   "Gov Arm Keys":ser.dropna().isin(gov_arm_keys).mean(), 
                   "Country Gov Arm Keys":ser.dropna().isin(country_gov_arm_keys).mean(), 
                   "Known Keys":ser.dropna().isin(known_keys).mean()}
pd.DataFrame.from_dict({code:fxn(df[code])for code in ["Actor1Code", "Actor2Code"]})
# Out:
#                       Actor1Code  Actor2Code
# Sparsity                0.077113    0.259698
# Country Keys            0.550827    0.549435
# Role Keys               0.274190    0.267856
# Country Role Keys       0.106052    0.114304
# Gov Arm Keys            0.007836    0.007310
# Country Gov Arm Keys    0.005899    0.004417
# Known Keys              0.944805    0.943322

# %%
# Map

# Case 1: Can be mapped from known codes
# map_ = {**country_code_map, **role_code_map, **country_role_code_map, **gov_arm_code_map, **country_gov_arm_code_map, **{np.nan: "NULL"}}
map_ = {**country_code_map, **role_code_map, **country_role_code_map, **gov_arm_code_map, **country_gov_arm_code_map}
df["Actor1Role"] = df["Actor1Code"].map(map_).str.upper()
df["Actor2Role"] = df["Actor2Code"].map(map_).str.upper()

# Case 2: Code available but not mapped
df["Actor1Role"] = df.apply(lambda row: "UNKNOWN" if not pd.isna(row["Actor1Code"]) and pd.isna(row["Actor1Role"]) else row["Actor1Role"], axis=1)
df["Actor2Role"] = df.apply(lambda row: "UNKNOWN" if not pd.isna(row["Actor2Code"]) and pd.isna(row["Actor2Role"]) else row["Actor2Role"], axis=1)

# Case 3: No code available
df["Actor1Role"] = df["Actor1Role"].fillna("NULL")
df["Actor2Role"] = df["Actor2Role"].fillna("NULL")

# %%
# Map interaction between actors
map_ = {
    **{k:"COUNTRY" for k in country_keys}, 
    **{k:"ROLE" for k in role_keys}, 
    **{k:"COUNTRY ROLE" for k in country_role_keys}, 
    **{k:"GOV ARM" for k in gov_arm_keys}, 
    **{k:"COUNTRY GOV ARM" for k in country_gov_arm_keys}, 
    **{"UNKNOWN": "UNKNOWN", "NULL": "NULL"}
}
df["Actor1Group"] = df["Actor1Code"].map(map_)
df["Actor2Group"] = df["Actor2Code"].map(map_)
df["Actor1Group"] = df.apply(lambda row: row["Actor1Role"] if row["Actor1Role"] in ["UNKNOWN", "NULL"] else row["Actor1Group"], axis=1)
df["Actor2Group"] = df.apply(lambda row: row["Actor2Role"] if row["Actor2Role"] in ["UNKNOWN", "NULL"] else row["Actor1Group"], axis=1)

df["ActorRoleInteraction"] = df["Actor1Group"] + "-" + df["Actor2Group"]
df["ActorEquivalentRoles"] = df["Actor1Group"] == df["Actor2Group"]

df["ActorRoleInteraction"].value_counts(normalize=True).head()
df["ActorEquivalentRoles"].value_counts(normalize=True).head()
# Out:
# ActorRoleInteraction
# COUNTRY-COUNTRY              0.352747
# ROLE-ROLE                    0.151077
# COUNTRY-NULL                 0.132287
# ROLE-NULL                    0.094211
# COUNTRY ROLE-COUNTRY ROLE    0.076466
# Name: proportion, dtype: float64
# ActorEquivalentRoles
# True     0.701982
# False    0.298018
# Name: proportion, dtype: float64

# %%
# Check if code lengths are in multiples of 3
tmp = df[[c for c in df.columns if c[-4:]=="Code"]].melt(value_name="code", var_name="code_type").dropna()
tmp["code_len"] = tmp["code"].str.len()
tmp.pivot_table(index="code_type", columns="code_len", values="code", aggfunc="count", fill_value=0)
# Out:
# code_len               3       6      9     12   15
# code_type
# Actor1Code         682852  109788  19598  2793  148
# Actor1CountryCode  555669       0      0     0    0
# Actor2Code         543256   93206  15155  2156  130
# Actor2CountryCode  449358       0      0     0    0

# %%
# Check if there are unexpected values among country codes
country_codes_w_in_data = tmp.query("code_type.isin(['Actor1CountryCode', 'Actor2CountryCode'])")["code"]
country_codes_w_in_data[country_codes_w_in_data.map(country_code_map).isna()].drop_duplicates().values.tolist()
# Out:
# []

# %%
# Recode by splitting into 3-chars
insert_wspace_every_3_chars = lambda x: " ".join([x[i:i+3] for i in range(0, len(str(x)), 3)])
df["Actor1Code"] = df["Actor1Code"].apply(lambda x: insert_wspace_every_3_chars(str(x)) if (len(str(x))<3) or pd.isna(x)==False else x)
df["Actor2Code"] = df["Actor2Code"].apply(lambda x: insert_wspace_every_3_chars(str(x)) if (len(str(x))<3) or pd.isna(x)==False else x)

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <ul>
#         <li> No issues found in <b>QuadClass, SQLDATE, CAMEOEvent, EventDateTime</b>.</li>
#         <li><b>Actor1CountryCode</b> and <b>Actor2CountryCode</b> represents only one country at a time using string of charater length 3. No unexpected values found. <i>Exact string-matching rule is appropriate.</i></li>
#         <li><b>Actor1CCode</b> and <b>Actor2Code</b> has character lengths in multiples of 3 between 3 to 15. This translates to 1-5 coded groups. <i>Jaccard or token set ratio are appropriate string comparison metrics.</i></li>
#     </ul>
# </div>

# %%
# Use up to 3
df["Actor1Geo_FullName"].dropna().str.count(",").value_counts(normalize=True).sort_index().cumsum()
# Out:
# Actor1Geo_FullName
# 0    0.207913
# 1    0.243015
# 2    0.973200
# 3    0.999995
# 4    1.000000
# Name: proportion, dtype: float64

# %%
# Split geo into sections
df["Actor1Geo_Country"] = df["Actor1Geo_FullName"].str.split(",").str[-1]
df["Actor1Geo_Region"] = df["Actor1Geo_FullName"].str.split(",").str[-2]
df["Actor1Geo_City"] = df["Actor1Geo_FullName"].str.split(",").str[-3]
df["Actor2Geo_Country"] = df["Actor2Geo_FullName"].str.split(",").str[-1]
df["Actor2Geo_Region"] = df["Actor2Geo_FullName"].str.split(",").str[-2]
df["Actor2Geo_City"] = df["Actor2Geo_FullName"].str.split(",").str[-3]

df.iloc[:10,-6:]  # Preview
# Out:
#               Actor1Geo_Country Actor1Geo_Region Actor1Geo_City  \
# GLOBALEVENTID
# 1078326026                  NaN              NaN            NaN
# 1078326027                  NaN              NaN            NaN
# 1078326030                  NaN              NaN            NaN
# 1078326080                  NaN              NaN            NaN
# 1078326081                  NaN              NaN            NaN
# 1078326209                China          Beijing        Beijing
# 1078326246                  NaN              NaN            NaN
# 1078326357               Russia           Moskva         Moscow
# 1078326359               Russia           Moskva         Moscow
# 1078326399        United States     Pennsylvania  Monroe County
#
#               Actor2Geo_Country Actor2Geo_Region Actor2Geo_City
# GLOBALEVENTID
# 1078326026                  NaN              NaN            NaN
# 1078326027                  NaN              NaN            NaN
# 1078326030                  NaN              NaN            NaN
# 1078326080               Russia           Moskva         Moscow
# 1078326081        United States     Pennsylvania  Monroe County
# 1078326209                  NaN              NaN            NaN
# 1078326246                  NaN              NaN            NaN
# 1078326357               Russia           Moskva         Moscow
# 1078326359               Russia           Moskva         Moscow
# 1078326399                  NaN              NaN            NaN

# %%
# Limit to 1 year
lim = df["SQLDATE"].drop_duplicates().sort_values(ascending=False)[365]
df = df[df["SQLDATE"]>=lim]
df = df.drop(columns=["SQLDATE"], axis=1)
df.shape
# Out:
# /var/folders/d9/xf7h513s2dz2psys_kb_1gyr0000gq/T/ipykernel_9218/3243869962.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   lim = df["SQLDATE"].drop_duplicates().sort_values(ascending=False)[365]
# (756655, 24)

# %%
# Rearrage cols
df = df[[
    "EventDateTime",
    "QuadClass",
    "CAMEOEvent",
    "GoldsteinScore",
    "Actor1Name",
    "Actor1Code",
    "Actor1Role",
    "Actor1Group",
    "Actor2Name",
    "Actor2Code",
    "Actor2Role",
    "Actor2Group",
    "ActorRoleInteraction",
    "ActorEquivalentRoles",
    "Actor1CountryCode",
    "Actor1Geo_FullName",
    "Actor1Geo_Country",
    "Actor1Geo_Region",
    "Actor1Geo_City",
    "Actor2CountryCode",
    "Actor2Geo_FullName",
    "Actor2Geo_Country",
    "Actor2Geo_Region",
    "Actor2Geo_City"
]]

# %%
# Describe
df.describe()

df.describe(include="O")
# Out:
#                        EventDateTime  GoldsteinScore
# count                         756655   756655.000000
# mean   2023-09-11 09:21:44.880163328        0.545647
# min              2023-03-17 00:00:00      -10.000000
# 25%              2023-06-20 04:00:00       -2.000000
# 50%              2023-09-15 01:00:00        1.900000
# 75%              2023-11-27 05:15:00        3.400000
# max              2024-03-16 11:30:00       10.000000
# std                              NaN        4.635200
#        QuadClass CAMEOEvent  Actor1Name Actor1Code   Actor1Role Actor1Group  \
# count     756655     756655      699026     699026       756655      756655
# unique         4        227        3404       2810         1721           7
# top            1        010  PHILIPPINE        PHL  PHILIPPINES     COUNTRY
# freq      473878      65987      107013     123312       123312      386584
#
#         Actor2Name Actor2Code Actor2Role Actor2Group  ... Actor1CountryCode  \
# count       561732     561732     756655      756655  ...            479253
# unique        3190       2604       1627           7  ...               216
# top     PHILIPPINE        PHL       NULL     COUNTRY  ...               PHL
# freq         79886      87107     194923      268965  ...            144014
#
#                  Actor1Geo_FullName Actor1Geo_Country Actor1Geo_Region  \
# count                        681511            681511           539644
# unique                         9065               418             1750
# top     Manila, Manila, Philippines       Philippines           Manila
# freq                          55608            235183            55765
#
#        Actor1Geo_City Actor2CountryCode           Actor2Geo_FullName  \
# count          515136            388140                       551933
# unique           8417               214                         8202
# top            Manila               PHL  Manila, Manila, Philippines
# freq            55608            104685                        43015
#
#        Actor2Geo_Country Actor2Geo_Region Actor2Geo_City
# count             551933           434612         416573
# unique               414             1684           7601
# top          Philippines           Manila         Manila
# freq              178945            43136          43015
#
# [4 rows x 21 columns]

# %%
from src.lib.utils.helper_functions import test_for_independence
cat_cols = df.select_dtypes(include="O").columns
pairwise_cols = [(c, c_) for i, c in enumerate(cat_cols) for c_ in cat_cols[i:] if c!=c_]
results = {}
for a, b in pairwise_cols:
    subset = df[[a, b]].dropna()
    if subset.size > 1:
        try:
            results[(a, b)] = test_for_independence(subset[a], subset[b])
        except Exception as e:
            if "No data; `observed` has size 0." in e.args[0]:
                print(f"Crosstab between {a}, {b} has 0s.")
results = pd.DataFrame.from_dict(results, orient="index")
results["S.Sig"] = results["P-value"] < 0.01
results
# Out:
# /Users/Hancee/Library/Caches/pypoetry/virtualenvs/counter-news-QfaVnN7T-py3.9/lib/python3.9/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
# Crosstab between QuadClass, CAMEOEvent has 0s.
# Crosstab between QuadClass, Actor1Name has 0s.
# Crosstab between QuadClass, Actor1Code has 0s.
# Crosstab between QuadClass, Actor1Role has 0s.
# Crosstab between QuadClass, Actor1Group has 0s.
# Crosstab between QuadClass, Actor2Name has 0s.
# Crosstab between QuadClass, Actor2Code has 0s.
# Crosstab between QuadClass, Actor2Role has 0s.
# Crosstab between QuadClass, Actor2Group has 0s.
# Crosstab between QuadClass, ActorRoleInteraction has 0s.
# Crosstab between QuadClass, Actor1CountryCode has 0s.
# Crosstab between QuadClass, Actor1Geo_FullName has 0s.
# Crosstab between QuadClass, Actor1Geo_Country has 0s.
# Crosstab between QuadClass, Actor1Geo_Region has 0s.
# Crosstab between QuadClass, Actor1Geo_City has 0s.
# Crosstab between QuadClass, Actor2CountryCode has 0s.
# Crosstab between QuadClass, Actor2Geo_FullName has 0s.
# Crosstab between QuadClass, Actor2Geo_Country has 0s.
# Crosstab between QuadClass, Actor2Geo_Region has 0s.
# Crosstab between QuadClass, Actor2Geo_City has 0s.
# Crosstab between CAMEOEvent, Actor1Name has 0s.
# Crosstab between CAMEOEvent, Actor1Code has 0s.
# Crosstab between CAMEOEvent, Actor1Role has 0s.
# Crosstab between CAMEOEvent, Actor1Group has 0s.
# Crosstab between CAMEOEvent, Actor2Name has 0s.
# Crosstab between CAMEOEvent, Actor2Code has 0s.
# Crosstab between CAMEOEvent, Actor2Role has 0s.
# Crosstab between CAMEOEvent, Actor2Group has 0s.
# Crosstab between CAMEOEvent, ActorRoleInteraction has 0s.
# Crosstab between CAMEOEvent, Actor1CountryCode has 0s.
# Crosstab between CAMEOEvent, Actor1Geo_FullName has 0s.
# Crosstab between CAMEOEvent, Actor1Geo_Country has 0s.
# Crosstab between CAMEOEvent, Actor1Geo_Region has 0s.
# Crosstab between CAMEOEvent, Actor1Geo_City has 0s.
# Crosstab between CAMEOEvent, Actor2CountryCode has 0s.
# Crosstab between CAMEOEvent, Actor2Geo_FullName has 0s.
# Crosstab between CAMEOEvent, Actor2Geo_Country has 0s.
# Crosstab between CAMEOEvent, Actor2Geo_Region has 0s.
# Crosstab between CAMEOEvent, Actor2Geo_City has 0s.
# Crosstab between Actor1Name, Actor1Code has 0s.
# Crosstab between Actor1Name, Actor1Group has 0s.
# Crosstab between Actor1Name, Actor2Code has 0s.
# Crosstab between Actor1Name, Actor2Group has 0s.
# Crosstab between Actor1Name, ActorRoleInteraction has 0s.
# Crosstab between Actor1Name, Actor1CountryCode has 0s.
# Crosstab between Actor1Name, Actor1Geo_FullName has 0s.
# Crosstab between Actor1Name, Actor1Geo_Country has 0s.
# Crosstab between Actor1Name, Actor1Geo_Region has 0s.
# Crosstab between Actor1Name, Actor1Geo_City has 0s.
# Crosstab between Actor1Name, Actor2CountryCode has 0s.
# Crosstab between Actor1Name, Actor2Geo_FullName has 0s.
# Crosstab between Actor1Name, Actor2Geo_Country has 0s.
# Crosstab between Actor1Name, Actor2Geo_Region has 0s.
# Crosstab between Actor1Name, Actor2Geo_City has 0s.
# Crosstab between Actor1Code, Actor1Group has 0s.
# Crosstab between Actor1Code, Actor2Name has 0s.
# Crosstab between Actor1Code, Actor2Group has 0s.
# Crosstab between Actor1Code, ActorRoleInteraction has 0s.
# Crosstab between Actor1Code, Actor1Geo_FullName has 0s.
# Crosstab between Actor1Code, Actor1Geo_Country has 0s.
# Crosstab between Actor1Code, Actor1Geo_Region has 0s.
# Crosstab between Actor1Code, Actor1Geo_City has 0s.
# Crosstab between Actor1Code, Actor2Geo_FullName has 0s.
# Crosstab between Actor1Code, Actor2Geo_Country has 0s.
# Crosstab between Actor1Code, Actor2Geo_Region has 0s.
# Crosstab between Actor1Code, Actor2Geo_City has 0s.
# Crosstab between Actor1Role, ActorRoleInteraction has 0s.
# Crosstab between Actor1Role, Actor1CountryCode has 0s.
# Crosstab between Actor1Role, Actor1Geo_FullName has 0s.
# Crosstab between Actor1Role, Actor1Geo_Country has 0s.
# Crosstab between Actor1Role, Actor1Geo_Region has 0s.
# Crosstab between Actor1Role, Actor1Geo_City has 0s.
# Crosstab between Actor1Role, Actor2CountryCode has 0s.
# Crosstab between Actor1Role, Actor2Geo_FullName has 0s.
# Crosstab between Actor1Role, Actor2Geo_Country has 0s.
# Crosstab between Actor1Role, Actor2Geo_Region has 0s.
# Crosstab between Actor1Role, Actor2Geo_City has 0s.
# Crosstab between Actor1Group, Actor2Name has 0s.
# Crosstab between Actor1Group, Actor2Code has 0s.
# Crosstab between Actor1Group, ActorRoleInteraction has 0s.
# Crosstab between Actor1Group, Actor1CountryCode has 0s.
# Crosstab between Actor1Group, Actor1Geo_FullName has 0s.
# Crosstab between Actor1Group, Actor1Geo_Country has 0s.
# Crosstab between Actor1Group, Actor1Geo_Region has 0s.
# Crosstab between Actor1Group, Actor1Geo_City has 0s.
# Crosstab between Actor1Group, Actor2CountryCode has 0s.
# Crosstab between Actor1Group, Actor2Geo_FullName has 0s.
# Crosstab between Actor1Group, Actor2Geo_Country has 0s.
# Crosstab between Actor1Group, Actor2Geo_Region has 0s.
# Crosstab between Actor1Group, Actor2Geo_City has 0s.
# Crosstab between Actor2Name, Actor2Code has 0s.
# Crosstab between Actor2Name, Actor2Group has 0s.
# Crosstab between Actor2Name, ActorRoleInteraction has 0s.
# Crosstab between Actor2Name, Actor1CountryCode has 0s.
# Crosstab between Actor2Name, Actor1Geo_FullName has 0s.
# Crosstab between Actor2Name, Actor1Geo_Country has 0s.
# Crosstab between Actor2Name, Actor1Geo_Region has 0s.
# Crosstab between Actor2Name, Actor1Geo_City has 0s.
# Crosstab between Actor2Name, Actor2CountryCode has 0s.
# Crosstab between Actor2Name, Actor2Geo_FullName has 0s.
# Crosstab between Actor2Name, Actor2Geo_Country has 0s.
# Crosstab between Actor2Name, Actor2Geo_Region has 0s.
# Crosstab between Actor2Name, Actor2Geo_City has 0s.
# Crosstab between Actor2Code, Actor2Group has 0s.
# Crosstab between Actor2Code, ActorRoleInteraction has 0s.
# Crosstab between Actor2Code, Actor1Geo_FullName has 0s.
# Crosstab between Actor2Code, Actor1Geo_Country has 0s.
# Crosstab between Actor2Code, Actor1Geo_Region has 0s.
# Crosstab between Actor2Code, Actor1Geo_City has 0s.
# Crosstab between Actor2Code, Actor2Geo_FullName has 0s.
# Crosstab between Actor2Code, Actor2Geo_Country has 0s.
# Crosstab between Actor2Code, Actor2Geo_Region has 0s.
# Crosstab between Actor2Code, Actor2Geo_City has 0s.
# Crosstab between Actor2Role, ActorRoleInteraction has 0s.
# Crosstab between Actor2Role, Actor1CountryCode has 0s.
# Crosstab between Actor2Role, Actor1Geo_FullName has 0s.
# Crosstab between Actor2Role, Actor1Geo_Country has 0s.
# Crosstab between Actor2Role, Actor1Geo_Region has 0s.
# Crosstab between Actor2Role, Actor1Geo_City has 0s.
# Crosstab between Actor2Role, Actor2CountryCode has 0s.
# Crosstab between Actor2Role, Actor2Geo_FullName has 0s.
# Crosstab between Actor2Role, Actor2Geo_Country has 0s.
# Crosstab between Actor2Role, Actor2Geo_Region has 0s.
# Crosstab between Actor2Role, Actor2Geo_City has 0s.
# Crosstab between Actor2Group, ActorRoleInteraction has 0s.
# Crosstab between Actor2Group, Actor1CountryCode has 0s.
# Crosstab between Actor2Group, Actor1Geo_FullName has 0s.
# Crosstab between Actor2Group, Actor1Geo_Country has 0s.
# Crosstab between Actor2Group, Actor1Geo_Region has 0s.
# Crosstab between Actor2Group, Actor1Geo_City has 0s.
# Crosstab between Actor2Group, Actor2CountryCode has 0s.
# Crosstab between Actor2Group, Actor2Geo_FullName has 0s.
# Crosstab between Actor2Group, Actor2Geo_Country has 0s.
# Crosstab between Actor2Group, Actor2Geo_Region has 0s.
# Crosstab between Actor2Group, Actor2Geo_City has 0s.
# Crosstab between ActorRoleInteraction, Actor1CountryCode has 0s.
# Crosstab between ActorRoleInteraction, Actor1Geo_FullName has 0s.
# Crosstab between ActorRoleInteraction, Actor1Geo_Country has 0s.
# Crosstab between ActorRoleInteraction, Actor1Geo_Region has 0s.
# Crosstab between ActorRoleInteraction, Actor1Geo_City has 0s.
# Crosstab between ActorRoleInteraction, Actor2CountryCode has 0s.
# Crosstab between ActorRoleInteraction, Actor2Geo_FullName has 0s.
# Crosstab between ActorRoleInteraction, Actor2Geo_Country has 0s.
# Crosstab between ActorRoleInteraction, Actor2Geo_Region has 0s.
# Crosstab between ActorRoleInteraction, Actor2Geo_City has 0s.
# Crosstab between Actor1CountryCode, Actor1Geo_FullName has 0s.
# Crosstab between Actor1CountryCode, Actor1Geo_Country has 0s.
# Crosstab between Actor1CountryCode, Actor1Geo_Region has 0s.
# Crosstab between Actor1CountryCode, Actor1Geo_City has 0s.
# Crosstab between Actor1CountryCode, Actor2Geo_FullName has 0s.
# Crosstab between Actor1CountryCode, Actor2Geo_Country has 0s.
# Crosstab between Actor1CountryCode, Actor2Geo_Region has 0s.
# Crosstab between Actor1CountryCode, Actor2Geo_City has 0s.
# Crosstab between Actor1Geo_FullName, Actor1Geo_Region has 0s.
# Crosstab between Actor1Geo_FullName, Actor1Geo_City has 0s.
# Crosstab between Actor1Geo_FullName, Actor2CountryCode has 0s.
# Crosstab between Actor1Geo_FullName, Actor2Geo_City has 0s.
# Crosstab between Actor1Geo_Country, Actor2CountryCode has 0s.
# Crosstab between Actor1Geo_Region, Actor1Geo_City has 0s.
# Crosstab between Actor1Geo_Region, Actor2CountryCode has 0s.
# Crosstab between Actor1Geo_City, Actor2CountryCode has 0s.
# Crosstab between Actor1Geo_City, Actor2Geo_FullName has 0s.
# Crosstab between Actor2CountryCode, Actor2Geo_FullName has 0s.
# Crosstab between Actor2CountryCode, Actor2Geo_Country has 0s.
# Crosstab between Actor2CountryCode, Actor2Geo_Region has 0s.
# Crosstab between Actor2CountryCode, Actor2Geo_City has 0s.
# Crosstab between Actor2Geo_FullName, Actor2Geo_Region has 0s.
# Crosstab between Actor2Geo_FullName, Actor2Geo_City has 0s.
# Crosstab between Actor2Geo_Region, Actor2Geo_City has 0s.
#                                               Test      Statistic  \
# Actor1Name         Actor1Role          CHI SQUARED   44950.272543
#                    Actor2Name          CHI SQUARED   21388.641825
#                    Actor2Role          CHI SQUARED   32493.030139
# Actor1Code         Actor1Role          CHI SQUARED       0.000000
#                    Actor2Code          CHI SQUARED   13160.093160
#                    Actor2Role          CHI SQUARED       0.000000
#                    Actor1CountryCode   CHI SQUARED    4519.141007
#                    Actor2CountryCode   CHI SQUARED    7204.103893
# Actor1Role         Actor1Group         CHI SQUARED       0.000000
#                    Actor2Name          CHI SQUARED   30612.440179
#                    Actor2Code          CHI SQUARED       0.000000
#                    Actor2Role          CHI SQUARED  102886.461085
#                    Actor2Group         CHI SQUARED   18170.508161
# Actor1Group        Actor2Role          CHI SQUARED   27084.052667
#                    Actor2Group         CHI SQUARED  166926.232888
# Actor2Name         Actor2Role          CHI SQUARED   31135.388365
# Actor2Code         Actor2Role          CHI SQUARED       0.000000
#                    Actor1CountryCode   CHI SQUARED   10576.798822
#                    Actor2CountryCode   CHI SQUARED    3531.665360
# Actor2Role         Actor2Group         CHI SQUARED    2238.994974
# Actor1CountryCode  Actor2CountryCode   CHI SQUARED    2054.918793
# Actor1Geo_FullName Actor1Geo_Country   CHI SQUARED       0.000000
#                    Actor2Geo_FullName  CHI SQUARED    2697.962781
#                    Actor2Geo_Country   CHI SQUARED     315.145917
#                    Actor2Geo_Region    CHI SQUARED       0.000000
# Actor1Geo_Country  Actor1Geo_Region    CHI SQUARED     336.070536
#                    Actor1Geo_City      CHI SQUARED       0.000000
#                    Actor2Geo_FullName  CHI SQUARED     315.145917
#                    Actor2Geo_Country   CHI SQUARED     600.692963
#                    Actor2Geo_Region    CHI SQUARED     184.426077
#                    Actor2Geo_City      CHI SQUARED       0.000000
# Actor1Geo_Region   Actor2Geo_FullName  CHI SQUARED       0.000000
#                    Actor2Geo_Country   CHI SQUARED     201.529677
#                    Actor2Geo_Region    CHI SQUARED     623.639769
#                    Actor2Geo_City      CHI SQUARED       0.000000
# Actor1Geo_City     Actor2Geo_Country   CHI SQUARED       0.000000
#                    Actor2Geo_Region    CHI SQUARED       0.000000
#                    Actor2Geo_City      CHI SQUARED    1675.459816
# Actor2Geo_FullName Actor2Geo_Country   CHI SQUARED       0.000000
# Actor2Geo_Country  Actor2Geo_Region    CHI SQUARED     227.315808
#                    Actor2Geo_City      CHI SQUARED       0.000000
#
#                                              P-value  S.Sig
# Actor1Name         Actor1Role           0.000000e+00   True
#                    Actor2Name           0.000000e+00   True
#                    Actor2Role           0.000000e+00   True
# Actor1Code         Actor1Role           1.000000e+00  False
#                    Actor2Code           0.000000e+00   True
#                    Actor2Role           1.000000e+00  False
#                    Actor1CountryCode    0.000000e+00   True
#                    Actor2CountryCode    0.000000e+00   True
# Actor1Role         Actor1Group          1.000000e+00  False
#                    Actor2Name           0.000000e+00   True
#                    Actor2Code           1.000000e+00  False
#                    Actor2Role           0.000000e+00   True
#                    Actor2Group          0.000000e+00   True
# Actor1Group        Actor2Role           0.000000e+00   True
#                    Actor2Group          0.000000e+00   True
# Actor2Name         Actor2Role           0.000000e+00   True
# Actor2Code         Actor2Role           1.000000e+00  False
#                    Actor1CountryCode    0.000000e+00   True
#                    Actor2CountryCode    0.000000e+00   True
# Actor2Role         Actor2Group          0.000000e+00   True
# Actor1CountryCode  Actor2CountryCode   1.089124e-299   True
# Actor1Geo_FullName Actor1Geo_Country    1.000000e+00  False
#                    Actor2Geo_FullName   1.000000e+00  False
#                    Actor2Geo_Country    9.973163e-06   True
#                    Actor2Geo_Region     1.000000e+00  False
# Actor1Geo_Country  Actor1Geo_Region     1.054898e-73   True
#                    Actor1Geo_City       1.000000e+00  False
#                    Actor2Geo_FullName   9.973163e-06   True
#                    Actor2Geo_Country    1.535444e-09   True
#                    Actor2Geo_Region     9.762777e-40   True
#                    Actor2Geo_City       1.000000e+00  False
# Actor1Geo_Region   Actor2Geo_FullName   1.000000e+00  False
#                    Actor2Geo_Country    1.970767e-43   True
#                    Actor2Geo_Region     1.000000e+00  False
#                    Actor2Geo_City       1.000000e+00  False
# Actor1Geo_City     Actor2Geo_Country    1.000000e+00  False
#                    Actor2Geo_Region     1.000000e+00  False
#                    Actor2Geo_City       1.000000e+00  False
# Actor2Geo_FullName Actor2Geo_Country    1.000000e+00  False
# Actor2Geo_Country  Actor2Geo_Region     4.355113e-50   True
#                    Actor2Geo_City       1.000000e+00  False

# %%
# Export
df.to_parquet(PROJECT_DIRECTORY.joinpath("data/explored/explored_docs.parquet"), index=True, compression="gzip")
